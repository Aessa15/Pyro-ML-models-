# %% [markdown]
# # Regression and DNN Model

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import pydot
import time
import datetime

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
import kerastuner as kt
from tensorflow.keras.layers.experimental import preprocessing
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error


print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# # Get Dataset

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(url, names=column_names,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

dataset = raw_dataset.copy()
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1

# %% [markdown]
# # Check Null values

# %%
#The dataset contains a few unknown values.
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
#Drop those rows to keep this initial tutorial simple.
dataset = dataset.dropna()

# %% [markdown]
# ## Data Adjusting

# %%
dataset['Origin'] = dataset['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
dataset = pd.get_dummies(dataset, prefix='', prefix_sep='')
dataset.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-0b452f475108> in <module>
# ----> 1 dataset['Origin'] = dataset['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
#       2 dataset = pd.get_dummies(dataset, prefix='', prefix_sep='')
#       3 dataset.tail()
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Origin'

# %% [markdown]
# # Splitting Data to training and testing data

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)



test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['MPG', 'Cylinders', 'Displacement', 'Weight']], diag_kind='kde')

# %%
train_dataset.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%  \
# MPG           314.0    23.310510    7.728652    10.0    17.00    22.0
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# Europe        314.0     0.178344    0.383413     0.0     0.00     0.0
# Japan         314.0     0.197452    0.398712     0.0     0.00     0.0
# USA           314.0     0.624204    0.485101     0.0     0.00     1.0
#
#                   75%     max
# MPG             28.95    46.6
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# Europe           0.00     1.0
# Japan            0.00     1.0
# USA              1.00     1.0

# %%
#Separate the target value, the "label", from the features. This label is the value that you will train the model to predict.
train_features = train_dataset.copy()
test_features = test_dataset.copy()


train_labels = train_features[['MPG','Weight']].copy()

train_features = train_features.drop(['MPG','Weight'], axis=1)

test_labels = test_features[['MPG','Weight']].copy()

test_features = test_features.drop(['MPG','Weight'], axis=1)

# %%
#In the table of statistics it's easy to see how different the ranges of each feature are.
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#                      mean         std
# MPG             23.310510    7.728652
# Cylinders        5.477707    1.699788
# Displacement   195.318471  104.331589
# Horsepower     104.869427   38.096214
# Weight        2990.251592  843.898596
# Acceleration    15.559236    2.789230
# Model Year      75.898089    3.675642
# Europe           0.178344    0.383413
# Japan            0.197452    0.398712
# USA              0.624204    0.485101

# %% [markdown]
# # Data Normalization

# %%
normalizer = preprocessing.Normalization()

normalizer.adapt(np.array(train_features))

print(normalizer.mean.numpy())

print(type(normalizer))
# Out:
# [  5.478 195.318 104.869  15.559  75.898   0.178   0.197   0.624]
# <class 'tensorflow.python.keras.layers.preprocessing.normalization.Normalization'>

# %%
first = np.array(train_features[:1])
tx = np.array(train_features)


with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[ 4.  90.  75.  14.5 74.   0.   0.   1. ]]
#
# Normalized: [[-0.87 -1.01 -0.79 -0.38 -0.52 -0.47 -0.5   0.78]]

# %% [markdown]
# # Keras Functional API Model

# %%
def build_and_compile_model_0(norm):
    model = keras.Sequential([
        norm,
        layers.Dense(128, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(128, activation='relu'),
        layers.Dense(2, activation='linear')
  ])

    model.compile(loss=['mean_absolute_error'], optimizer=tf.keras.optimizers.Adam(0.001),metrics=[keras.metrics.MeanAbsoluteError()]
    )
    return model
    
Name = 'ANN multioutputs regression '+ datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
Tensor_Board = keras.callbacks.TensorBoard(
    log_dir="../Model_0/Name/{}".format(Name),
    histogram_freq=0,  # How often to log histogram visualizations
    embeddings_freq=0,  # How often to log embedding visualizations
    update_freq="epoch",
)  # How often to write logs (default: once per epoch)

# %%
dnn_model = build_and_compile_model_0(normalizer)

# %%
#dnn_model.summary()

# %%
keras.utils.plot_model(dnn_model, "multi_input_and_output_model.png", show_shapes=True)

# %%
# %%time
history = dnn_model.fit(train_features, y=(train_labels), batch_size=64, epochs=500, callbacks= Tensor_Board,validation_split=0.1)
# Out:
# Epoch 1/360
# 5/5 [==============================] - 2s 433ms/step - loss: 1494.2121 - mean_absolute_error: 1494.2121 - val_loss: 1566.8770 - val_mean_absolute_error: 1566.8770
# Epoch 2/360
# 5/5 [==============================] - 0s 26ms/step - loss: 1492.1311 - mean_absolute_error: 1492.1311 - val_loss: 1566.1777 - val_mean_absolute_error: 1566.1777
# Epoch 3/360
# 5/5 [==============================] - 0s 32ms/step - loss: 1484.1776 - mean_absolute_error: 1484.1776 - val_loss: 1564.9921 - val_mean_absolute_error: 1564.9921
# Epoch 4/360
# 5/5 [==============================] - 0s 44ms/step - loss: 1494.2084 - mean_absolute_error: 1494.2084 - val_loss: 1562.9330 - val_mean_absolute_error: 1562.9330
# Epoch 5/360
# 5/5 [==============================] - 0s 83ms/step - loss: 1494.4764 - mean_absolute_error: 1494.4764 - val_loss: 1559.5293 - val_mean_absolute_error: 1559.5293
# Epoch 6/360
# 5/5 [==============================] - 0s 43ms/step - loss: 1471.3327 - mean_absolute_error: 1471.3327 - val_loss: 1555.0748 - val_mean_absolute_error: 1555.0748
# Epoch 7/360
# 5/5 [==============================] - 0s 31ms/step - loss: 1498.2882 - mean_absolute_error: 1498.2882 - val_loss: 1549.6194 - val_mean_absolute_error: 1549.6194
# Epoch 8/360
# 5/5 [==============================] - 0s 26ms/step - loss: 1472.0032 - mean_absolute_error: 1472.0032 - val_loss: 1545.5254 - val_mean_absolute_error: 1545.5254
# Epoch 9/360
# 5/5 [==============================] - 0s 26ms/step - loss: 1471.4492 - mean_absolute_error: 1471.4492 - val_loss: 1540.0774 - val_mean_absolute_error: 1540.0774
# Epoch 10/360
# 5/5 [==============================] - 0s 39ms/step - loss: 1473.7256 - mean_absolute_error: 1473.7256 - val_loss: 1532.1187 - val_mean_absolute_error: 1532.1187
# Epoch 11/360
# 5/5 [==============================] - 0s 41ms/step - loss: 1462.2091 - mean_absolute_error: 1462.2091 - val_loss: 1521.0720 - val_mean_absolute_error: 1521.0720
# Epoch 12/360
# 5/5 [==============================] - 0s 40ms/step - loss: 1440.6132 - mean_absolute_error: 1440.6132 - val_loss: 1505.3420 - val_mean_absolute_error: 1505.3420
# Epoch 13/360
# 5/5 [==============================] - 0s 35ms/step - loss: 1441.4963 - mean_absolute_error: 1441.4963 - val_loss: 1483.1871 - val_mean_absolute_error: 1483.1871
# Epoch 14/360
# 5/5 [==============================] - 0s 25ms/step - loss: 1403.4860 - mean_absolute_error: 1403.4860 - val_loss: 1452.9404 - val_mean_absolute_error: 1452.9404
# Epoch 15/360
# 5/5 [==============================] - 0s 23ms/step - loss: 1390.2076 - mean_absolute_error: 1390.2076 - val_loss: 1411.9725 - val_mean_absolute_error: 1411.9725
# Epoch 16/360
# 5/5 [==============================] - 0s 28ms/step - loss: 1329.8285 - mean_absolute_error: 1329.8285 - val_loss: 1357.5741 - val_mean_absolute_error: 1357.5741
# Epoch 17/360
# 5/5 [==============================] - 0s 42ms/step - loss: 1263.5145 - mean_absolute_error: 1263.5145 - val_loss: 1286.1754 - val_mean_absolute_error: 1286.1754
# Epoch 18/360
# 5/5 [==============================] - 0s 49ms/step - loss: 1220.1507 - mean_absolute_error: 1220.1507 - val_loss: 1195.2339 - val_mean_absolute_error: 1195.2339
# Epoch 19/360
# 5/5 [==============================] - 0s 42ms/step - loss: 1089.7589 - mean_absolute_error: 1089.7589 - val_loss: 1080.5726 - val_mean_absolute_error: 1080.5726
# Epoch 20/360
# 5/5 [==============================] - 0s 41ms/step - loss: 1021.4743 - mean_absolute_error: 1021.4743 - val_loss: 938.5483 - val_mean_absolute_error: 938.5483
# Epoch 21/360
# 5/5 [==============================] - 0s 65ms/step - loss: 880.4502 - mean_absolute_error: 880.4502 - val_loss: 818.6326 - val_mean_absolute_error: 818.6326
# Epoch 22/360
# 5/5 [==============================] - 0s 49ms/step - loss: 791.7910 - mean_absolute_error: 791.7910 - val_loss: 716.8730 - val_mean_absolute_error: 716.8730
# Epoch 23/360
# 5/5 [==============================] - 0s 53ms/step - loss: 649.6093 - mean_absolute_error: 649.6093 - val_loss: 605.3438 - val_mean_absolute_error: 605.3438
# Epoch 24/360
# 5/5 [==============================] - 0s 40ms/step - loss: 579.7780 - mean_absolute_error: 579.7780 - val_loss: 494.8076 - val_mean_absolute_error: 494.8076
# Epoch 25/360
# 5/5 [==============================] - 0s 37ms/step - loss: 511.5961 - mean_absolute_error: 511.5961 - val_loss: 403.8564 - val_mean_absolute_error: 403.8564
# Epoch 26/360
# 5/5 [==============================] - 0s 25ms/step - loss: 428.4480 - mean_absolute_error: 428.4480 - val_loss: 396.8331 - val_mean_absolute_error: 396.8331
# Epoch 27/360
# 5/5 [==============================] - 0s 26ms/step - loss: 381.4803 - mean_absolute_error: 381.4803 - val_loss: 391.6353 - val_mean_absolute_error: 391.6353
# Epoch 28/360
# 5/5 [==============================] - 0s 27ms/step - loss: 354.5053 - mean_absolute_error: 354.5053 - val_loss: 378.5353 - val_mean_absolute_error: 378.5353
# Epoch 29/360
# 5/5 [==============================] - 0s 27ms/step - loss: 311.2140 - mean_absolute_error: 311.2140 - val_loss: 359.4102 - val_mean_absolute_error: 359.4102
# Epoch 30/360
# 5/5 [==============================] - 0s 27ms/step - loss: 300.1843 - mean_absolute_error: 300.1843 - val_loss: 331.8666 - val_mean_absolute_error: 331.8666
# Epoch 31/360
# 5/5 [==============================] - 0s 24ms/step - loss: 285.5827 - mean_absolute_error: 285.5827 - val_loss: 304.4751 - val_mean_absolute_error: 304.4751
# Epoch 32/360
# 5/5 [==============================] - 0s 36ms/step - loss: 268.3715 - mean_absolute_error: 268.3715 - val_loss: 281.3664 - val_mean_absolute_error: 281.3664
# Epoch 33/360
# 5/5 [==============================] - 0s 30ms/step - loss: 260.1938 - mean_absolute_error: 260.1938 - val_loss: 259.3979 - val_mean_absolute_error: 259.3979
# Epoch 34/360
# 5/5 [==============================] - 0s 33ms/step - loss: 228.2937 - mean_absolute_error: 228.2937 - val_loss: 243.0115 - val_mean_absolute_error: 243.0115
# Epoch 35/360
# 5/5 [==============================] - 0s 27ms/step - loss: 221.2528 - mean_absolute_error: 221.2528 - val_loss: 230.6540 - val_mean_absolute_error: 230.6540
# Epoch 36/360
# 5/5 [==============================] - 0s 27ms/step - loss: 226.3234 - mean_absolute_error: 226.3234 - val_loss: 219.8884 - val_mean_absolute_error: 219.8884
# Epoch 37/360
# 5/5 [==============================] - 0s 26ms/step - loss: 199.1294 - mean_absolute_error: 199.1294 - val_loss: 207.4672 - val_mean_absolute_error: 207.4672
# Epoch 38/360
# 5/5 [==============================] - 0s 27ms/step - loss: 188.4687 - mean_absolute_error: 188.4687 - val_loss: 199.3161 - val_mean_absolute_error: 199.3161
# Epoch 39/360
# 5/5 [==============================] - 0s 28ms/step - loss: 199.9716 - mean_absolute_error: 199.9716 - val_loss: 193.8529 - val_mean_absolute_error: 193.8529
# Epoch 40/360
# 5/5 [==============================] - 0s 26ms/step - loss: 195.1141 - mean_absolute_error: 195.1141 - val_loss: 189.2925 - val_mean_absolute_error: 189.2925
# Epoch 41/360
# 5/5 [==============================] - 0s 27ms/step - loss: 181.7166 - mean_absolute_error: 181.7166 - val_loss: 182.4501 - val_mean_absolute_error: 182.4501
# Epoch 42/360
# 5/5 [==============================] - 0s 27ms/step - loss: 186.6108 - mean_absolute_error: 186.6108 - val_loss: 176.1512 - val_mean_absolute_error: 176.1512
# Epoch 43/360
# 5/5 [==============================] - 0s 31ms/step - loss: 183.5406 - mean_absolute_error: 183.5406 - val_loss: 176.1594 - val_mean_absolute_error: 176.1594
# Epoch 44/360
# 5/5 [==============================] - 0s 29ms/step - loss: 170.5300 - mean_absolute_error: 170.5300 - val_loss: 175.6817 - val_mean_absolute_error: 175.6817
# Epoch 45/360
# 5/5 [==============================] - 0s 27ms/step - loss: 165.2282 - mean_absolute_error: 165.2282 - val_loss: 172.1839 - val_mean_absolute_error: 172.1839
# Epoch 46/360
# 5/5 [==============================] - 0s 29ms/step - loss: 168.0324 - mean_absolute_error: 168.0324 - val_loss: 168.9019 - val_mean_absolute_error: 168.9019
# Epoch 47/360
# 5/5 [==============================] - 0s 26ms/step - loss: 165.4652 - mean_absolute_error: 165.4652 - val_loss: 164.4912 - val_mean_absolute_error: 164.4912
# Epoch 48/360
# 5/5 [==============================] - 0s 27ms/step - loss: 152.2350 - mean_absolute_error: 152.2350 - val_loss: 161.4667 - val_mean_absolute_error: 161.4667
# Epoch 49/360
# 5/5 [==============================] - 0s 26ms/step - loss: 156.2409 - mean_absolute_error: 156.2409 - val_loss: 158.2630 - val_mean_absolute_error: 158.2630
# Epoch 50/360
# 5/5 [==============================] - 0s 27ms/step - loss: 156.2842 - mean_absolute_error: 156.2842 - val_loss: 152.5262 - val_mean_absolute_error: 152.5262
# Epoch 51/360
# 5/5 [==============================] - 0s 29ms/step - loss: 145.0570 - mean_absolute_error: 145.0570 - val_loss: 149.8372 - val_mean_absolute_error: 149.8372
# Epoch 52/360
# 5/5 [==============================] - 0s 27ms/step - loss: 151.0982 - mean_absolute_error: 151.0982 - val_loss: 147.8687 - val_mean_absolute_error: 147.8687
# Epoch 53/360
# 5/5 [==============================] - 0s 35ms/step - loss: 146.5030 - mean_absolute_error: 146.5030 - val_loss: 146.6245 - val_mean_absolute_error: 146.6245
# Epoch 54/360
# 5/5 [==============================] - 0s 40ms/step - loss: 143.5833 - mean_absolute_error: 143.5833 - val_loss: 146.0874 - val_mean_absolute_error: 146.0874
# Epoch 55/360
# 5/5 [==============================] - 0s 39ms/step - loss: 142.6501 - mean_absolute_error: 142.6501 - val_loss: 144.4671 - val_mean_absolute_error: 144.4671
# Epoch 56/360
# 5/5 [==============================] - 0s 30ms/step - loss: 143.2906 - mean_absolute_error: 143.2906 - val_loss: 144.0114 - val_mean_absolute_error: 144.0114
# Epoch 57/360
# 5/5 [==============================] - 0s 25ms/step - loss: 133.7900 - mean_absolute_error: 133.7900 - val_loss: 140.4977 - val_mean_absolute_error: 140.4977
# Epoch 58/360
# 5/5 [==============================] - 0s 27ms/step - loss: 136.0691 - mean_absolute_error: 136.0691 - val_loss: 137.7749 - val_mean_absolute_error: 137.7749
# Epoch 59/360
# 5/5 [==============================] - 0s 26ms/step - loss: 136.8456 - mean_absolute_error: 136.8456 - val_loss: 135.5687 - val_mean_absolute_error: 135.5687
# Epoch 60/360
# 5/5 [==============================] - 0s 29ms/step - loss: 139.1393 - mean_absolute_error: 139.1393 - val_loss: 133.0638 - val_mean_absolute_error: 133.0638
# Epoch 61/360
# 5/5 [==============================] - 0s 25ms/step - loss: 131.5162 - mean_absolute_error: 131.5162 - val_loss: 135.9371 - val_mean_absolute_error: 135.9371
# Epoch 62/360
# 5/5 [==============================] - 0s 27ms/step - loss: 127.2101 - mean_absolute_error: 127.2101 - val_loss: 137.8040 - val_mean_absolute_error: 137.8040
# Epoch 63/360
# 5/5 [==============================] - 0s 29ms/step - loss: 137.5510 - mean_absolute_error: 137.5510 - val_loss: 136.7372 - val_mean_absolute_error: 136.7372
# Epoch 64/360
# 5/5 [==============================] - 0s 27ms/step - loss: 131.2516 - mean_absolute_error: 131.2516 - val_loss: 133.7220 - val_mean_absolute_error: 133.7220
# Epoch 65/360
# 5/5 [==============================] - 0s 24ms/step - loss: 129.1414 - mean_absolute_error: 129.1414 - val_loss: 130.4442 - val_mean_absolute_error: 130.4442
# Epoch 66/360
# 5/5 [==============================] - 0s 26ms/step - loss: 132.5222 - mean_absolute_error: 132.5222 - val_loss: 134.7504 - val_mean_absolute_error: 134.7504
# Epoch 67/360
# 5/5 [==============================] - 0s 29ms/step - loss: 126.7232 - mean_absolute_error: 126.7232 - val_loss: 134.6669 - val_mean_absolute_error: 134.6669
# Epoch 68/360
# 5/5 [==============================] - 0s 29ms/step - loss: 125.7377 - mean_absolute_error: 125.7377 - val_loss: 134.9194 - val_mean_absolute_error: 134.9194
# Epoch 69/360
# 5/5 [==============================] - 0s 26ms/step - loss: 126.4751 - mean_absolute_error: 126.4751 - val_loss: 131.7061 - val_mean_absolute_error: 131.7061
# Epoch 70/360
# 5/5 [==============================] - 0s 26ms/step - loss: 120.8613 - mean_absolute_error: 120.8613 - val_loss: 129.6174 - val_mean_absolute_error: 129.6174
# Epoch 71/360
# 5/5 [==============================] - 0s 29ms/step - loss: 123.6994 - mean_absolute_error: 123.6994 - val_loss: 129.2965 - val_mean_absolute_error: 129.2965
# Epoch 72/360
# 5/5 [==============================] - 0s 25ms/step - loss: 121.5951 - mean_absolute_error: 121.5951 - val_loss: 130.3979 - val_mean_absolute_error: 130.3979
# Epoch 73/360
# 5/5 [==============================] - 0s 27ms/step - loss: 117.8498 - mean_absolute_error: 117.8498 - val_loss: 129.2793 - val_mean_absolute_error: 129.2793
# Epoch 74/360
# 5/5 [==============================] - 0s 25ms/step - loss: 122.2105 - mean_absolute_error: 122.2105 - val_loss: 127.8860 - val_mean_absolute_error: 127.8860
# Epoch 75/360
# 5/5 [==============================] - 0s 27ms/step - loss: 114.4246 - mean_absolute_error: 114.4246 - val_loss: 129.3434 - val_mean_absolute_error: 129.3434
# Epoch 76/360
# 5/5 [==============================] - 0s 29ms/step - loss: 123.7433 - mean_absolute_error: 123.7433 - val_loss: 130.5941 - val_mean_absolute_error: 130.5941
# Epoch 77/360
# 5/5 [==============================] - 0s 39ms/step - loss: 113.7839 - mean_absolute_error: 113.7839 - val_loss: 129.6478 - val_mean_absolute_error: 129.6478
# Epoch 78/360
# 5/5 [==============================] - 0s 35ms/step - loss: 121.2652 - mean_absolute_error: 121.2652 - val_loss: 127.3067 - val_mean_absolute_error: 127.3067
# Epoch 79/360
# 5/5 [==============================] - 0s 38ms/step - loss: 114.3559 - mean_absolute_error: 114.3559 - val_loss: 125.5799 - val_mean_absolute_error: 125.5799
# Epoch 80/360
# 5/5 [==============================] - 0s 27ms/step - loss: 109.2217 - mean_absolute_error: 109.2217 - val_loss: 128.1170 - val_mean_absolute_error: 128.1170
# Epoch 81/360
# 5/5 [==============================] - 0s 28ms/step - loss: 114.4725 - mean_absolute_error: 114.4725 - val_loss: 128.5415 - val_mean_absolute_error: 128.5415
# Epoch 82/360
# 5/5 [==============================] - 0s 26ms/step - loss: 108.4814 - mean_absolute_error: 108.4814 - val_loss: 128.6153 - val_mean_absolute_error: 128.6153
# Epoch 83/360
# 5/5 [==============================] - 0s 26ms/step - loss: 114.2703 - mean_absolute_error: 114.2703 - val_loss: 129.5506 - val_mean_absolute_error: 129.5506
# Epoch 84/360
# 5/5 [==============================] - 0s 28ms/step - loss: 106.6248 - mean_absolute_error: 106.6248 - val_loss: 128.1733 - val_mean_absolute_error: 128.1733
# Epoch 85/360
# 5/5 [==============================] - 0s 27ms/step - loss: 107.0213 - mean_absolute_error: 107.0213 - val_loss: 125.3539 - val_mean_absolute_error: 125.3539
# Epoch 86/360
# 5/5 [==============================] - 0s 28ms/step - loss: 115.6479 - mean_absolute_error: 115.6479 - val_loss: 123.8652 - val_mean_absolute_error: 123.8652
# Epoch 87/360
# 5/5 [==============================] - 0s 27ms/step - loss: 116.6712 - mean_absolute_error: 116.6712 - val_loss: 124.7893 - val_mean_absolute_error: 124.7893
# Epoch 88/360
# 5/5 [==============================] - 0s 29ms/step - loss: 109.9363 - mean_absolute_error: 109.9363 - val_loss: 128.4083 - val_mean_absolute_error: 128.4083
# Epoch 89/360
# 5/5 [==============================] - 0s 28ms/step - loss: 111.1613 - mean_absolute_error: 111.1613 - val_loss: 130.2560 - val_mean_absolute_error: 130.2560
# Epoch 90/360
# 5/5 [==============================] - 0s 29ms/step - loss: 107.9100 - mean_absolute_error: 107.9100 - val_loss: 129.7218 - val_mean_absolute_error: 129.7218
# Epoch 91/360
# 5/5 [==============================] - 0s 26ms/step - loss: 114.2860 - mean_absolute_error: 114.2860 - val_loss: 123.8898 - val_mean_absolute_error: 123.8898
# Epoch 92/360
# 5/5 [==============================] - 0s 36ms/step - loss: 110.9228 - mean_absolute_error: 110.9228 - val_loss: 124.5014 - val_mean_absolute_error: 124.5014
# Epoch 93/360
# 5/5 [==============================] - 0s 44ms/step - loss: 108.6134 - mean_absolute_error: 108.6134 - val_loss: 126.6513 - val_mean_absolute_error: 126.6513
# Epoch 94/360
# 5/5 [==============================] - 0s 40ms/step - loss: 108.0702 - mean_absolute_error: 108.0702 - val_loss: 123.0197 - val_mean_absolute_error: 123.0197
# Epoch 95/360
# 5/5 [==============================] - 0s 33ms/step - loss: 102.2783 - mean_absolute_error: 102.2783 - val_loss: 122.1904 - val_mean_absolute_error: 122.1904
# Epoch 96/360
# 5/5 [==============================] - 0s 26ms/step - loss: 106.8520 - mean_absolute_error: 106.8520 - val_loss: 124.1373 - val_mean_absolute_error: 124.1373
# Epoch 97/360
# 5/5 [==============================] - 0s 26ms/step - loss: 102.7012 - mean_absolute_error: 102.7012 - val_loss: 120.2337 - val_mean_absolute_error: 120.2337
# Epoch 98/360
# 5/5 [==============================] - 0s 29ms/step - loss: 101.2253 - mean_absolute_error: 101.2253 - val_loss: 121.0282 - val_mean_absolute_error: 121.0282
# Epoch 99/360
# 5/5 [==============================] - 0s 29ms/step - loss: 100.0062 - mean_absolute_error: 100.0062 - val_loss: 126.1611 - val_mean_absolute_error: 126.1611
# Epoch 100/360
# 5/5 [==============================] - 0s 26ms/step - loss: 109.6660 - mean_absolute_error: 109.6660 - val_loss: 125.1251 - val_mean_absolute_error: 125.1251
# Epoch 101/360
# 5/5 [==============================] - 0s 28ms/step - loss: 105.7737 - mean_absolute_error: 105.7737 - val_loss: 125.5672 - val_mean_absolute_error: 125.5672
# Epoch 102/360
# 5/5 [==============================] - 0s 27ms/step - loss: 98.9471 - mean_absolute_error: 98.9471 - val_loss: 123.2636 - val_mean_absolute_error: 123.2636
# Epoch 103/360
# 5/5 [==============================] - 0s 26ms/step - loss: 97.2606 - mean_absolute_error: 97.2606 - val_loss: 120.3989 - val_mean_absolute_error: 120.3989
# Epoch 104/360
# 5/5 [==============================] - 0s 28ms/step - loss: 98.3604 - mean_absolute_error: 98.3604 - val_loss: 121.3362 - val_mean_absolute_error: 121.3362
# Epoch 105/360
# 5/5 [==============================] - 0s 27ms/step - loss: 98.5612 - mean_absolute_error: 98.5612 - val_loss: 121.0765 - val_mean_absolute_error: 121.0765
# Epoch 106/360
# 5/5 [==============================] - 0s 26ms/step - loss: 97.3663 - mean_absolute_error: 97.3663 - val_loss: 123.3372 - val_mean_absolute_error: 123.3372
# Epoch 107/360
# 5/5 [==============================] - 0s 27ms/step - loss: 99.8771 - mean_absolute_error: 99.8771 - val_loss: 126.0238 - val_mean_absolute_error: 126.0238
# Epoch 108/360
# 5/5 [==============================] - 0s 27ms/step - loss: 104.5111 - mean_absolute_error: 104.5111 - val_loss: 124.3277 - val_mean_absolute_error: 124.3277
# Epoch 109/360
# 5/5 [==============================] - 0s 27ms/step - loss: 100.4007 - mean_absolute_error: 100.4007 - val_loss: 122.0219 - val_mean_absolute_error: 122.0219
# Epoch 110/360
# 5/5 [==============================] - 0s 27ms/step - loss: 100.3270 - mean_absolute_error: 100.3270 - val_loss: 121.9698 - val_mean_absolute_error: 121.9698
# Epoch 111/360
# 5/5 [==============================] - 0s 26ms/step - loss: 92.8177 - mean_absolute_error: 92.8177 - val_loss: 122.2638 - val_mean_absolute_error: 122.2638
# Epoch 112/360
# 5/5 [==============================] - 0s 31ms/step - loss: 95.2643 - mean_absolute_error: 95.2643 - val_loss: 120.5767 - val_mean_absolute_error: 120.5767
# Epoch 113/360
# 5/5 [==============================] - 0s 27ms/step - loss: 95.7864 - mean_absolute_error: 95.7864 - val_loss: 121.7610 - val_mean_absolute_error: 121.7610
# Epoch 114/360
# 5/5 [==============================] - 0s 27ms/step - loss: 93.4633 - mean_absolute_error: 93.4633 - val_loss: 122.3627 - val_mean_absolute_error: 122.3627
# Epoch 115/360
# 5/5 [==============================] - 0s 27ms/step - loss: 96.1479 - mean_absolute_error: 96.1479 - val_loss: 120.2918 - val_mean_absolute_error: 120.2918
# Epoch 116/360
# 5/5 [==============================] - 0s 31ms/step - loss: 94.9588 - mean_absolute_error: 94.9588 - val_loss: 120.6378 - val_mean_absolute_error: 120.6378
# Epoch 117/360
# 5/5 [==============================] - 0s 29ms/step - loss: 98.4681 - mean_absolute_error: 98.4681 - val_loss: 120.4807 - val_mean_absolute_error: 120.4807
# Epoch 118/360
# 5/5 [==============================] - 0s 28ms/step - loss: 102.1181 - mean_absolute_error: 102.1181 - val_loss: 120.8483 - val_mean_absolute_error: 120.8483
# Epoch 119/360
# 5/5 [==============================] - 0s 26ms/step - loss: 95.3125 - mean_absolute_error: 95.3125 - val_loss: 122.6800 - val_mean_absolute_error: 122.6800
# Epoch 120/360
# 5/5 [==============================] - 0s 28ms/step - loss: 99.4023 - mean_absolute_error: 99.4023 - val_loss: 119.8107 - val_mean_absolute_error: 119.8107
# Epoch 121/360
# 5/5 [==============================] - 0s 31ms/step - loss: 94.3010 - mean_absolute_error: 94.3010 - val_loss: 121.7580 - val_mean_absolute_error: 121.7580
# Epoch 122/360
# 5/5 [==============================] - 0s 26ms/step - loss: 99.5030 - mean_absolute_error: 99.5030 - val_loss: 122.2470 - val_mean_absolute_error: 122.2470
# Epoch 123/360
# 5/5 [==============================] - 0s 29ms/step - loss: 89.4141 - mean_absolute_error: 89.4141 - val_loss: 118.2169 - val_mean_absolute_error: 118.2169
# Epoch 124/360
# 5/5 [==============================] - 0s 26ms/step - loss: 100.0881 - mean_absolute_error: 100.0881 - val_loss: 117.3401 - val_mean_absolute_error: 117.3401
# Epoch 125/360
# 5/5 [==============================] - 0s 39ms/step - loss: 95.5137 - mean_absolute_error: 95.5137 - val_loss: 120.1222 - val_mean_absolute_error: 120.1222
# Epoch 126/360
# 5/5 [==============================] - 0s 28ms/step - loss: 98.2914 - mean_absolute_error: 98.2914 - val_loss: 119.9534 - val_mean_absolute_error: 119.9534
# Epoch 127/360
# 5/5 [==============================] - 0s 27ms/step - loss: 90.2998 - mean_absolute_error: 90.2998 - val_loss: 118.3879 - val_mean_absolute_error: 118.3879
# Epoch 128/360
# 5/5 [==============================] - 0s 25ms/step - loss: 90.2793 - mean_absolute_error: 90.2793 - val_loss: 117.6634 - val_mean_absolute_error: 117.6634
# Epoch 129/360
# 5/5 [==============================] - 0s 30ms/step - loss: 94.2320 - mean_absolute_error: 94.2320 - val_loss: 119.7535 - val_mean_absolute_error: 119.7535
# Epoch 130/360
# 5/5 [==============================] - 0s 27ms/step - loss: 94.3891 - mean_absolute_error: 94.3891 - val_loss: 119.9254 - val_mean_absolute_error: 119.9254
# Epoch 131/360
# 5/5 [==============================] - 0s 29ms/step - loss: 94.8046 - mean_absolute_error: 94.8046 - val_loss: 117.7886 - val_mean_absolute_error: 117.7886
# Epoch 132/360
# 5/5 [==============================] - 0s 44ms/step - loss: 99.8416 - mean_absolute_error: 99.8416 - val_loss: 120.7374 - val_mean_absolute_error: 120.7374
# Epoch 133/360
# 5/5 [==============================] - 0s 40ms/step - loss: 93.0287 - mean_absolute_error: 93.0287 - val_loss: 119.4479 - val_mean_absolute_error: 119.4479
# Epoch 134/360
# 5/5 [==============================] - 0s 38ms/step - loss: 91.1065 - mean_absolute_error: 91.1065 - val_loss: 117.3887 - val_mean_absolute_error: 117.3887
# Epoch 135/360
# 5/5 [==============================] - 0s 34ms/step - loss: 93.6593 - mean_absolute_error: 93.6593 - val_loss: 121.6006 - val_mean_absolute_error: 121.6006
# Epoch 136/360
# 5/5 [==============================] - 0s 28ms/step - loss: 90.3427 - mean_absolute_error: 90.3427 - val_loss: 120.5760 - val_mean_absolute_error: 120.5760
# Epoch 137/360
# 5/5 [==============================] - 0s 28ms/step - loss: 93.2037 - mean_absolute_error: 93.2037 - val_loss: 116.2685 - val_mean_absolute_error: 116.2685
# Epoch 138/360
# 5/5 [==============================] - 0s 27ms/step - loss: 92.6846 - mean_absolute_error: 92.6846 - val_loss: 121.7903 - val_mean_absolute_error: 121.7903
# Epoch 139/360
# 5/5 [==============================] - 0s 26ms/step - loss: 92.3465 - mean_absolute_error: 92.3465 - val_loss: 121.3729 - val_mean_absolute_error: 121.3729
# Epoch 140/360
# 5/5 [==============================] - 0s 30ms/step - loss: 91.9057 - mean_absolute_error: 91.9057 - val_loss: 116.2615 - val_mean_absolute_error: 116.2615
# Epoch 141/360
# 5/5 [==============================] - 0s 27ms/step - loss: 99.1135 - mean_absolute_error: 99.1135 - val_loss: 115.7446 - val_mean_absolute_error: 115.7446
# Epoch 142/360
# 5/5 [==============================] - 0s 27ms/step - loss: 92.7077 - mean_absolute_error: 92.7077 - val_loss: 119.7296 - val_mean_absolute_error: 119.7296
# Epoch 143/360
# 5/5 [==============================] - 0s 28ms/step - loss: 86.4746 - mean_absolute_error: 86.4746 - val_loss: 116.9965 - val_mean_absolute_error: 116.9965
# Epoch 144/360
# 5/5 [==============================] - 0s 31ms/step - loss: 90.9681 - mean_absolute_error: 90.9681 - val_loss: 117.6213 - val_mean_absolute_error: 117.6213
# Epoch 145/360
# 5/5 [==============================] - 0s 32ms/step - loss: 88.0720 - mean_absolute_error: 88.0720 - val_loss: 120.1342 - val_mean_absolute_error: 120.1342
# Epoch 146/360
# 5/5 [==============================] - 0s 29ms/step - loss: 86.9982 - mean_absolute_error: 86.9982 - val_loss: 121.2951 - val_mean_absolute_error: 121.2951
# Epoch 147/360
# 5/5 [==============================] - 0s 28ms/step - loss: 90.5622 - mean_absolute_error: 90.5622 - val_loss: 120.5880 - val_mean_absolute_error: 120.5880
# Epoch 148/360
# 5/5 [==============================] - 0s 30ms/step - loss: 91.6431 - mean_absolute_error: 91.6431 - val_loss: 117.5450 - val_mean_absolute_error: 117.5450
# Epoch 149/360
# 5/5 [==============================] - 0s 26ms/step - loss: 88.5161 - mean_absolute_error: 88.5161 - val_loss: 112.6488 - val_mean_absolute_error: 112.6488
# Epoch 150/360
# 5/5 [==============================] - 0s 24ms/step - loss: 96.1694 - mean_absolute_error: 96.1694 - val_loss: 115.7119 - val_mean_absolute_error: 115.7119
# Epoch 151/360
# 5/5 [==============================] - 0s 23ms/step - loss: 86.2142 - mean_absolute_error: 86.2142 - val_loss: 118.9596 - val_mean_absolute_error: 118.9596
# Epoch 152/360
# 5/5 [==============================] - 0s 23ms/step - loss: 92.0673 - mean_absolute_error: 92.0673 - val_loss: 119.5209 - val_mean_absolute_error: 119.5209
# Epoch 153/360
# 5/5 [==============================] - 0s 27ms/step - loss: 88.9033 - mean_absolute_error: 88.9033 - val_loss: 115.8811 - val_mean_absolute_error: 115.8811
# Epoch 154/360
# 5/5 [==============================] - 0s 26ms/step - loss: 94.5840 - mean_absolute_error: 94.5840 - val_loss: 119.3145 - val_mean_absolute_error: 119.3145
# Epoch 155/360
# 5/5 [==============================] - 0s 23ms/step - loss: 84.7353 - mean_absolute_error: 84.7353 - val_loss: 118.5029 - val_mean_absolute_error: 118.5029
# Epoch 156/360
# 5/5 [==============================] - 0s 23ms/step - loss: 85.7723 - mean_absolute_error: 85.7723 - val_loss: 119.3595 - val_mean_absolute_error: 119.3595
# Epoch 157/360
# 5/5 [==============================] - 0s 26ms/step - loss: 87.2224 - mean_absolute_error: 87.2224 - val_loss: 121.9671 - val_mean_absolute_error: 121.9671
# Epoch 158/360
# 5/5 [==============================] - 0s 26ms/step - loss: 92.0771 - mean_absolute_error: 92.0771 - val_loss: 118.2519 - val_mean_absolute_error: 118.2519
# Epoch 159/360
# 5/5 [==============================] - 0s 24ms/step - loss: 88.0949 - mean_absolute_error: 88.0949 - val_loss: 115.5922 - val_mean_absolute_error: 115.5922
# Epoch 160/360
# 5/5 [==============================] - 0s 24ms/step - loss: 90.8593 - mean_absolute_error: 90.8593 - val_loss: 119.2740 - val_mean_absolute_error: 119.2740
# Epoch 161/360
# 5/5 [==============================] - 0s 25ms/step - loss: 81.9883 - mean_absolute_error: 81.9883 - val_loss: 117.1529 - val_mean_absolute_error: 117.1529
# Epoch 162/360
# 5/5 [==============================] - 0s 26ms/step - loss: 90.4014 - mean_absolute_error: 90.4014 - val_loss: 111.4197 - val_mean_absolute_error: 111.4197
# Epoch 163/360
# 5/5 [==============================] - 0s 26ms/step - loss: 91.7094 - mean_absolute_error: 91.7094 - val_loss: 120.5771 - val_mean_absolute_error: 120.5771
# Epoch 164/360
# 5/5 [==============================] - 0s 31ms/step - loss: 88.6373 - mean_absolute_error: 88.6373 - val_loss: 117.5808 - val_mean_absolute_error: 117.5808
# Epoch 165/360
# 5/5 [==============================] - 0s 23ms/step - loss: 90.0957 - mean_absolute_error: 90.0957 - val_loss: 119.1655 - val_mean_absolute_error: 119.1655
# Epoch 166/360
# 5/5 [==============================] - 0s 25ms/step - loss: 81.5047 - mean_absolute_error: 81.5047 - val_loss: 119.7049 - val_mean_absolute_error: 119.7049
# Epoch 167/360
# 5/5 [==============================] - 0s 26ms/step - loss: 87.7131 - mean_absolute_error: 87.7131 - val_loss: 118.5738 - val_mean_absolute_error: 118.5738
# Epoch 168/360
# 5/5 [==============================] - 0s 24ms/step - loss: 90.2834 - mean_absolute_error: 90.2834 - val_loss: 113.0139 - val_mean_absolute_error: 113.0139
# Epoch 169/360
# 5/5 [==============================] - 0s 23ms/step - loss: 90.0299 - mean_absolute_error: 90.0299 - val_loss: 115.4580 - val_mean_absolute_error: 115.4580
# Epoch 170/360
# 5/5 [==============================] - 0s 24ms/step - loss: 90.1804 - mean_absolute_error: 90.1804 - val_loss: 119.4116 - val_mean_absolute_error: 119.4116
# Epoch 171/360
# 5/5 [==============================] - 0s 26ms/step - loss: 88.3402 - mean_absolute_error: 88.3402 - val_loss: 115.7600 - val_mean_absolute_error: 115.7600
# Epoch 172/360
# 5/5 [==============================] - 0s 25ms/step - loss: 85.5987 - mean_absolute_error: 85.5987 - val_loss: 117.6966 - val_mean_absolute_error: 117.6966
# Epoch 173/360
# 5/5 [==============================] - 0s 33ms/step - loss: 83.3872 - mean_absolute_error: 83.3872 - val_loss: 117.8396 - val_mean_absolute_error: 117.8396
# Epoch 174/360
# 5/5 [==============================] - 0s 36ms/step - loss: 86.1176 - mean_absolute_error: 86.1176 - val_loss: 117.2535 - val_mean_absolute_error: 117.2535
# Epoch 175/360
# 5/5 [==============================] - 0s 40ms/step - loss: 82.7294 - mean_absolute_error: 82.7294 - val_loss: 116.3095 - val_mean_absolute_error: 116.3095
# Epoch 176/360
# 5/5 [==============================] - 0s 29ms/step - loss: 88.3492 - mean_absolute_error: 88.3492 - val_loss: 115.4784 - val_mean_absolute_error: 115.4784
# Epoch 177/360
# 5/5 [==============================] - 0s 25ms/step - loss: 82.4267 - mean_absolute_error: 82.4267 - val_loss: 119.5177 - val_mean_absolute_error: 119.5177
# Epoch 178/360
# 5/5 [==============================] - 0s 33ms/step - loss: 88.8597 - mean_absolute_error: 88.8597 - val_loss: 114.2527 - val_mean_absolute_error: 114.2527
# Epoch 179/360
# 5/5 [==============================] - 0s 37ms/step - loss: 91.3700 - mean_absolute_error: 91.3700 - val_loss: 115.1446 - val_mean_absolute_error: 115.1446
# Epoch 180/360
# 5/5 [==============================] - 0s 32ms/step - loss: 84.7434 - mean_absolute_error: 84.7434 - val_loss: 115.9984 - val_mean_absolute_error: 115.9984
# Epoch 181/360
# 5/5 [==============================] - 0s 29ms/step - loss: 85.0863 - mean_absolute_error: 85.0863 - val_loss: 116.2237 - val_mean_absolute_error: 116.2237
# Epoch 182/360
# 5/5 [==============================] - 0s 34ms/step - loss: 83.9964 - mean_absolute_error: 83.9964 - val_loss: 117.3920 - val_mean_absolute_error: 117.3920
# Epoch 183/360
# 5/5 [==============================] - 0s 28ms/step - loss: 82.5323 - mean_absolute_error: 82.5323 - val_loss: 117.9136 - val_mean_absolute_error: 117.9136
# Epoch 184/360
# 5/5 [==============================] - 0s 29ms/step - loss: 85.6224 - mean_absolute_error: 85.6224 - val_loss: 116.0797 - val_mean_absolute_error: 116.0797
# Epoch 185/360
# 5/5 [==============================] - 0s 34ms/step - loss: 79.4503 - mean_absolute_error: 79.4503 - val_loss: 117.3157 - val_mean_absolute_error: 117.3157
# Epoch 186/360
# 5/5 [==============================] - 0s 34ms/step - loss: 79.9892 - mean_absolute_error: 79.9892 - val_loss: 113.2728 - val_mean_absolute_error: 113.2728
# Epoch 187/360
# 5/5 [==============================] - 0s 39ms/step - loss: 81.2631 - mean_absolute_error: 81.2631 - val_loss: 115.9022 - val_mean_absolute_error: 115.9022
# Epoch 188/360
# 5/5 [==============================] - 0s 38ms/step - loss: 81.4933 - mean_absolute_error: 81.4933 - val_loss: 116.1715 - val_mean_absolute_error: 116.1715
# Epoch 189/360
# 5/5 [==============================] - 0s 42ms/step - loss: 86.9236 - mean_absolute_error: 86.9236 - val_loss: 116.0802 - val_mean_absolute_error: 116.0802
# Epoch 190/360
# 5/5 [==============================] - 0s 33ms/step - loss: 80.7539 - mean_absolute_error: 80.7539 - val_loss: 116.4711 - val_mean_absolute_error: 116.4711
# Epoch 191/360
# 5/5 [==============================] - 0s 29ms/step - loss: 85.3463 - mean_absolute_error: 85.3463 - val_loss: 116.1783 - val_mean_absolute_error: 116.1783
# Epoch 192/360
# 5/5 [==============================] - 0s 45ms/step - loss: 87.5560 - mean_absolute_error: 87.5560 - val_loss: 115.7449 - val_mean_absolute_error: 115.7449
# Epoch 193/360
# 5/5 [==============================] - 0s 37ms/step - loss: 80.6646 - mean_absolute_error: 80.6646 - val_loss: 118.8885 - val_mean_absolute_error: 118.8885
# Epoch 194/360
# 5/5 [==============================] - 0s 34ms/step - loss: 81.2028 - mean_absolute_error: 81.2028 - val_loss: 110.8706 - val_mean_absolute_error: 110.8706
# Epoch 195/360
# 5/5 [==============================] - 0s 44ms/step - loss: 86.8002 - mean_absolute_error: 86.8002 - val_loss: 110.9111 - val_mean_absolute_error: 110.9111
# Epoch 196/360
# 5/5 [==============================] - 0s 41ms/step - loss: 84.4387 - mean_absolute_error: 84.4387 - val_loss: 117.9081 - val_mean_absolute_error: 117.9081
# Epoch 197/360
# 5/5 [==============================] - 0s 32ms/step - loss: 84.5345 - mean_absolute_error: 84.5345 - val_loss: 111.6063 - val_mean_absolute_error: 111.6063
# Epoch 198/360
# 5/5 [==============================] - 0s 38ms/step - loss: 81.4097 - mean_absolute_error: 81.4097 - val_loss: 109.5361 - val_mean_absolute_error: 109.5361
# Epoch 199/360
# 5/5 [==============================] - 0s 42ms/step - loss: 83.6010 - mean_absolute_error: 83.6010 - val_loss: 110.4167 - val_mean_absolute_error: 110.4167
# Epoch 200/360
# 5/5 [==============================] - 0s 35ms/step - loss: 86.4667 - mean_absolute_error: 86.4667 - val_loss: 115.0426 - val_mean_absolute_error: 115.0426
# Epoch 201/360
# 5/5 [==============================] - 0s 35ms/step - loss: 85.2175 - mean_absolute_error: 85.2175 - val_loss: 111.3655 - val_mean_absolute_error: 111.3655
# Epoch 202/360
# 5/5 [==============================] - 0s 39ms/step - loss: 82.4719 - mean_absolute_error: 82.4719 - val_loss: 112.3349 - val_mean_absolute_error: 112.3349
# Epoch 203/360
# 5/5 [==============================] - 0s 36ms/step - loss: 77.4605 - mean_absolute_error: 77.4605 - val_loss: 115.0360 - val_mean_absolute_error: 115.0360
# Epoch 204/360
# 5/5 [==============================] - 0s 34ms/step - loss: 78.6693 - mean_absolute_error: 78.6693 - val_loss: 117.1214 - val_mean_absolute_error: 117.1214
# Epoch 205/360
# 5/5 [==============================] - 0s 38ms/step - loss: 82.8227 - mean_absolute_error: 82.8227 - val_loss: 118.5102 - val_mean_absolute_error: 118.5102
# Epoch 206/360
# 5/5 [==============================] - 0s 43ms/step - loss: 78.4739 - mean_absolute_error: 78.4739 - val_loss: 116.0194 - val_mean_absolute_error: 116.0194
# Epoch 207/360
# 5/5 [==============================] - 0s 40ms/step - loss: 82.7632 - mean_absolute_error: 82.7632 - val_loss: 112.3945 - val_mean_absolute_error: 112.3945
# Epoch 208/360
# 5/5 [==============================] - 0s 41ms/step - loss: 84.4271 - mean_absolute_error: 84.4271 - val_loss: 109.7233 - val_mean_absolute_error: 109.7233
# Epoch 209/360
# 5/5 [==============================] - 0s 38ms/step - loss: 82.4234 - mean_absolute_error: 82.4234 - val_loss: 110.7895 - val_mean_absolute_error: 110.7895
# Epoch 210/360
# 5/5 [==============================] - 0s 39ms/step - loss: 83.6314 - mean_absolute_error: 83.6314 - val_loss: 111.5875 - val_mean_absolute_error: 111.5875
# Epoch 211/360
# 5/5 [==============================] - 0s 40ms/step - loss: 80.2198 - mean_absolute_error: 80.2198 - val_loss: 113.5610 - val_mean_absolute_error: 113.5610
# Epoch 212/360
# 5/5 [==============================] - 0s 38ms/step - loss: 77.2526 - mean_absolute_error: 77.2526 - val_loss: 111.5611 - val_mean_absolute_error: 111.5611
# Epoch 213/360
# 5/5 [==============================] - 0s 28ms/step - loss: 85.1358 - mean_absolute_error: 85.1358 - val_loss: 112.5457 - val_mean_absolute_error: 112.5457
# Epoch 214/360
# 5/5 [==============================] - 0s 28ms/step - loss: 87.6000 - mean_absolute_error: 87.6000 - val_loss: 115.8543 - val_mean_absolute_error: 115.8543
# Epoch 215/360
# 5/5 [==============================] - 0s 27ms/step - loss: 81.0363 - mean_absolute_error: 81.0363 - val_loss: 114.3911 - val_mean_absolute_error: 114.3911
# Epoch 216/360
# 5/5 [==============================] - 0s 26ms/step - loss: 82.4113 - mean_absolute_error: 82.4113 - val_loss: 112.7711 - val_mean_absolute_error: 112.7711
# Epoch 217/360
# 5/5 [==============================] - 0s 31ms/step - loss: 83.1556 - mean_absolute_error: 83.1556 - val_loss: 111.3534 - val_mean_absolute_error: 111.3534
# Epoch 218/360
# 5/5 [==============================] - 0s 35ms/step - loss: 81.2574 - mean_absolute_error: 81.2574 - val_loss: 115.2104 - val_mean_absolute_error: 115.2104
# Epoch 219/360
# 5/5 [==============================] - 0s 39ms/step - loss: 78.7592 - mean_absolute_error: 78.7592 - val_loss: 113.7129 - val_mean_absolute_error: 113.7129
# Epoch 220/360
# 5/5 [==============================] - 0s 29ms/step - loss: 76.3731 - mean_absolute_error: 76.3731 - val_loss: 113.2354 - val_mean_absolute_error: 113.2354
# Epoch 221/360
# 5/5 [==============================] - 0s 27ms/step - loss: 84.2124 - mean_absolute_error: 84.2124 - val_loss: 113.5576 - val_mean_absolute_error: 113.5576
# Epoch 222/360
# 5/5 [==============================] - 0s 29ms/step - loss: 82.7539 - mean_absolute_error: 82.7539 - val_loss: 111.5828 - val_mean_absolute_error: 111.5828
# Epoch 223/360
# 5/5 [==============================] - 0s 40ms/step - loss: 85.0527 - mean_absolute_error: 85.0527 - val_loss: 111.5338 - val_mean_absolute_error: 111.5338
# Epoch 224/360
# 5/5 [==============================] - 0s 38ms/step - loss: 82.2234 - mean_absolute_error: 82.2234 - val_loss: 114.5227 - val_mean_absolute_error: 114.5227
# Epoch 225/360
# 5/5 [==============================] - 0s 35ms/step - loss: 81.4989 - mean_absolute_error: 81.4989 - val_loss: 111.3470 - val_mean_absolute_error: 111.3470
# Epoch 226/360
# 5/5 [==============================] - 0s 33ms/step - loss: 81.0634 - mean_absolute_error: 81.0634 - val_loss: 111.9269 - val_mean_absolute_error: 111.9269
# Epoch 227/360
# 5/5 [==============================] - 0s 27ms/step - loss: 80.8394 - mean_absolute_error: 80.8394 - val_loss: 110.7600 - val_mean_absolute_error: 110.7600
# Epoch 228/360
# 5/5 [==============================] - 0s 24ms/step - loss: 83.0225 - mean_absolute_error: 83.0225 - val_loss: 108.5251 - val_mean_absolute_error: 108.5251
# Epoch 229/360
# 5/5 [==============================] - 0s 23ms/step - loss: 84.1191 - mean_absolute_error: 84.1191 - val_loss: 111.9608 - val_mean_absolute_error: 111.9608
# Epoch 230/360
# 5/5 [==============================] - 0s 27ms/step - loss: 84.0138 - mean_absolute_error: 84.0138 - val_loss: 111.1601 - val_mean_absolute_error: 111.1601
# Epoch 231/360
# 5/5 [==============================] - 0s 28ms/step - loss: 80.3424 - mean_absolute_error: 80.3424 - val_loss: 110.6622 - val_mean_absolute_error: 110.6622
# Epoch 232/360
# 5/5 [==============================] - 0s 28ms/step - loss: 82.7209 - mean_absolute_error: 82.7209 - val_loss: 113.9648 - val_mean_absolute_error: 113.9648
# Epoch 233/360
# 5/5 [==============================] - 0s 28ms/step - loss: 78.7559 - mean_absolute_error: 78.7559 - val_loss: 111.5329 - val_mean_absolute_error: 111.5329
# Epoch 234/360
# 5/5 [==============================] - 0s 31ms/step - loss: 76.2704 - mean_absolute_error: 76.2704 - val_loss: 107.6405 - val_mean_absolute_error: 107.6405
# Epoch 235/360
# 5/5 [==============================] - 0s 27ms/step - loss: 82.3079 - mean_absolute_error: 82.3079 - val_loss: 107.4480 - val_mean_absolute_error: 107.4480
# Epoch 236/360
# 5/5 [==============================] - 0s 26ms/step - loss: 82.8770 - mean_absolute_error: 82.8770 - val_loss: 114.1117 - val_mean_absolute_error: 114.1117
# Epoch 237/360
# 5/5 [==============================] - 0s 25ms/step - loss: 81.0338 - mean_absolute_error: 81.0338 - val_loss: 108.7717 - val_mean_absolute_error: 108.7717
# Epoch 238/360
# 5/5 [==============================] - 0s 26ms/step - loss: 81.5486 - mean_absolute_error: 81.5486 - val_loss: 108.2387 - val_mean_absolute_error: 108.2387
# Epoch 239/360
# 5/5 [==============================] - 0s 35ms/step - loss: 77.7365 - mean_absolute_error: 77.7365 - val_loss: 109.6919 - val_mean_absolute_error: 109.6919
# Epoch 240/360
# 5/5 [==============================] - 0s 27ms/step - loss: 77.0689 - mean_absolute_error: 77.0689 - val_loss: 111.4473 - val_mean_absolute_error: 111.4473
# Epoch 241/360
# 5/5 [==============================] - 0s 36ms/step - loss: 75.6706 - mean_absolute_error: 75.6706 - val_loss: 108.8395 - val_mean_absolute_error: 108.8395
# Epoch 242/360
# 5/5 [==============================] - 0s 45ms/step - loss: 80.2367 - mean_absolute_error: 80.2367 - val_loss: 109.4486 - val_mean_absolute_error: 109.4486
# Epoch 243/360
# 5/5 [==============================] - 0s 38ms/step - loss: 77.9705 - mean_absolute_error: 77.9705 - val_loss: 110.1444 - val_mean_absolute_error: 110.1444
# Epoch 244/360
# 5/5 [==============================] - 0s 38ms/step - loss: 76.7826 - mean_absolute_error: 76.7826 - val_loss: 111.8747 - val_mean_absolute_error: 111.8747
# Epoch 245/360
# 5/5 [==============================] - 0s 37ms/step - loss: 75.9455 - mean_absolute_error: 75.9455 - val_loss: 112.3301 - val_mean_absolute_error: 112.3301
# Epoch 246/360
# 5/5 [==============================] - 0s 28ms/step - loss: 75.9440 - mean_absolute_error: 75.9440 - val_loss: 110.3180 - val_mean_absolute_error: 110.3180
# Epoch 247/360
# 5/5 [==============================] - 0s 27ms/step - loss: 76.5990 - mean_absolute_error: 76.5990 - val_loss: 109.4566 - val_mean_absolute_error: 109.4566
# Epoch 248/360
# 5/5 [==============================] - 0s 25ms/step - loss: 78.8844 - mean_absolute_error: 78.8844 - val_loss: 109.0292 - val_mean_absolute_error: 109.0292
# Epoch 249/360
# 5/5 [==============================] - 0s 26ms/step - loss: 81.4779 - mean_absolute_error: 81.4779 - val_loss: 111.6448 - val_mean_absolute_error: 111.6448
# Epoch 250/360
# 5/5 [==============================] - 0s 29ms/step - loss: 82.9945 - mean_absolute_error: 82.9945 - val_loss: 108.5839 - val_mean_absolute_error: 108.5839
# Epoch 251/360
# 5/5 [==============================] - 0s 24ms/step - loss: 82.9613 - mean_absolute_error: 82.9613 - val_loss: 106.7283 - val_mean_absolute_error: 106.7283
# Epoch 252/360
# 5/5 [==============================] - 0s 32ms/step - loss: 79.4178 - mean_absolute_error: 79.4178 - val_loss: 112.3345 - val_mean_absolute_error: 112.3345
# Epoch 253/360
# 5/5 [==============================] - 0s 32ms/step - loss: 80.1960 - mean_absolute_error: 80.1960 - val_loss: 110.1572 - val_mean_absolute_error: 110.1572
# Epoch 254/360
# 5/5 [==============================] - 0s 34ms/step - loss: 79.6564 - mean_absolute_error: 79.6564 - val_loss: 110.7955 - val_mean_absolute_error: 110.7955
# Epoch 255/360
# 5/5 [==============================] - 0s 28ms/step - loss: 79.0873 - mean_absolute_error: 79.0873 - val_loss: 110.5336 - val_mean_absolute_error: 110.5336
# Epoch 256/360
# 5/5 [==============================] - 0s 30ms/step - loss: 75.7906 - mean_absolute_error: 75.7906 - val_loss: 112.5001 - val_mean_absolute_error: 112.5001
# Epoch 257/360
# 5/5 [==============================] - 0s 29ms/step - loss: 81.3363 - mean_absolute_error: 81.3363 - val_loss: 109.1443 - val_mean_absolute_error: 109.1443
# Epoch 258/360
# 5/5 [==============================] - 0s 29ms/step - loss: 74.5106 - mean_absolute_error: 74.5106 - val_loss: 113.5082 - val_mean_absolute_error: 113.5082
# Epoch 259/360
# 5/5 [==============================] - 0s 30ms/step - loss: 85.3512 - mean_absolute_error: 85.3512 - val_loss: 113.2883 - val_mean_absolute_error: 113.2883
# Epoch 260/360
# 5/5 [==============================] - 0s 27ms/step - loss: 79.2568 - mean_absolute_error: 79.2568 - val_loss: 109.9363 - val_mean_absolute_error: 109.9363
# Epoch 261/360
# 5/5 [==============================] - 0s 30ms/step - loss: 75.1721 - mean_absolute_error: 75.1721 - val_loss: 107.4025 - val_mean_absolute_error: 107.4025
# Epoch 262/360
# 5/5 [==============================] - 0s 30ms/step - loss: 77.8969 - mean_absolute_error: 77.8969 - val_loss: 105.5551 - val_mean_absolute_error: 105.5551
# Epoch 263/360
# 5/5 [==============================] - 0s 28ms/step - loss: 79.7248 - mean_absolute_error: 79.7248 - val_loss: 106.0747 - val_mean_absolute_error: 106.0747
# Epoch 264/360
# 5/5 [==============================] - 0s 28ms/step - loss: 76.8985 - mean_absolute_error: 76.8985 - val_loss: 107.8823 - val_mean_absolute_error: 107.8823
# Epoch 265/360
# 5/5 [==============================] - 0s 29ms/step - loss: 76.7026 - mean_absolute_error: 76.7026 - val_loss: 112.7356 - val_mean_absolute_error: 112.7356
# Epoch 266/360
# 5/5 [==============================] - 0s 32ms/step - loss: 77.1099 - mean_absolute_error: 77.1099 - val_loss: 107.8055 - val_mean_absolute_error: 107.8055
# Epoch 267/360
# 5/5 [==============================] - 0s 27ms/step - loss: 76.5650 - mean_absolute_error: 76.5650 - val_loss: 107.2321 - val_mean_absolute_error: 107.2321
# Epoch 268/360
# 5/5 [==============================] - 0s 31ms/step - loss: 81.5616 - mean_absolute_error: 81.5616 - val_loss: 110.9301 - val_mean_absolute_error: 110.9301
# Epoch 269/360
# 5/5 [==============================] - 0s 31ms/step - loss: 82.7885 - mean_absolute_error: 82.7885 - val_loss: 113.0152 - val_mean_absolute_error: 113.0152
# Epoch 270/360
# 5/5 [==============================] - 0s 29ms/step - loss: 77.3098 - mean_absolute_error: 77.3098 - val_loss: 106.5637 - val_mean_absolute_error: 106.5637
# Epoch 271/360
# 5/5 [==============================] - 0s 27ms/step - loss: 87.0683 - mean_absolute_error: 87.0683 - val_loss: 106.2412 - val_mean_absolute_error: 106.2412
# Epoch 272/360
# 5/5 [==============================] - 0s 26ms/step - loss: 77.5892 - mean_absolute_error: 77.5892 - val_loss: 105.9883 - val_mean_absolute_error: 105.9883
# Epoch 273/360
# 5/5 [==============================] - 0s 25ms/step - loss: 74.5084 - mean_absolute_error: 74.5084 - val_loss: 108.3019 - val_mean_absolute_error: 108.3019
# Epoch 274/360
# 5/5 [==============================] - 0s 34ms/step - loss: 75.0403 - mean_absolute_error: 75.0403 - val_loss: 111.2212 - val_mean_absolute_error: 111.2212
# Epoch 275/360
# 5/5 [==============================] - 0s 27ms/step - loss: 77.9586 - mean_absolute_error: 77.9586 - val_loss: 109.7844 - val_mean_absolute_error: 109.7844
# Epoch 276/360
# 5/5 [==============================] - 0s 29ms/step - loss: 80.3445 - mean_absolute_error: 80.3445 - val_loss: 102.0565 - val_mean_absolute_error: 102.0565
# Epoch 277/360
# 5/5 [==============================] - 0s 29ms/step - loss: 76.5664 - mean_absolute_error: 76.5664 - val_loss: 107.9678 - val_mean_absolute_error: 107.9678
# Epoch 278/360
# 5/5 [==============================] - 0s 29ms/step - loss: 73.2454 - mean_absolute_error: 73.2454 - val_loss: 110.1476 - val_mean_absolute_error: 110.1476
# Epoch 279/360
# 5/5 [==============================] - 0s 41ms/step - loss: 78.9488 - mean_absolute_error: 78.9488 - val_loss: 109.8739 - val_mean_absolute_error: 109.8739
# Epoch 280/360
# 5/5 [==============================] - 0s 42ms/step - loss: 74.1683 - mean_absolute_error: 74.1683 - val_loss: 108.8843 - val_mean_absolute_error: 108.8843
# Epoch 281/360
# 5/5 [==============================] - 0s 43ms/step - loss: 75.8969 - mean_absolute_error: 75.8969 - val_loss: 107.7081 - val_mean_absolute_error: 107.7081
# Epoch 282/360
# 5/5 [==============================] - 0s 37ms/step - loss: 77.6152 - mean_absolute_error: 77.6152 - val_loss: 109.8681 - val_mean_absolute_error: 109.8681
# Epoch 283/360
# 5/5 [==============================] - 0s 27ms/step - loss: 76.9041 - mean_absolute_error: 76.9041 - val_loss: 103.9891 - val_mean_absolute_error: 103.9891
# Epoch 284/360
# 5/5 [==============================] - 0s 26ms/step - loss: 74.5710 - mean_absolute_error: 74.5710 - val_loss: 102.1996 - val_mean_absolute_error: 102.1996
# Epoch 285/360
# 5/5 [==============================] - 0s 36ms/step - loss: 77.2539 - mean_absolute_error: 77.2539 - val_loss: 106.0623 - val_mean_absolute_error: 106.0623
# Epoch 286/360
# 5/5 [==============================] - 0s 32ms/step - loss: 75.3426 - mean_absolute_error: 75.3426 - val_loss: 108.1959 - val_mean_absolute_error: 108.1959
# Epoch 287/360
# 5/5 [==============================] - 0s 26ms/step - loss: 78.8511 - mean_absolute_error: 78.8511 - val_loss: 108.6469 - val_mean_absolute_error: 108.6469
# Epoch 288/360
# 5/5 [==============================] - 0s 26ms/step - loss: 69.6500 - mean_absolute_error: 69.6500 - val_loss: 108.5946 - val_mean_absolute_error: 108.5946
# Epoch 289/360
# 5/5 [==============================] - 0s 31ms/step - loss: 77.8048 - mean_absolute_error: 77.8048 - val_loss: 107.0414 - val_mean_absolute_error: 107.0414
# Epoch 290/360
# 5/5 [==============================] - 0s 27ms/step - loss: 73.0618 - mean_absolute_error: 73.0618 - val_loss: 108.0949 - val_mean_absolute_error: 108.0949
# Epoch 291/360
# 5/5 [==============================] - 0s 29ms/step - loss: 78.2948 - mean_absolute_error: 78.2948 - val_loss: 110.3056 - val_mean_absolute_error: 110.3056
# Epoch 292/360
# 5/5 [==============================] - 0s 27ms/step - loss: 75.3569 - mean_absolute_error: 75.3569 - val_loss: 109.2292 - val_mean_absolute_error: 109.2292
# Epoch 293/360
# 5/5 [==============================] - 0s 45ms/step - loss: 72.8699 - mean_absolute_error: 72.8699 - val_loss: 105.3277 - val_mean_absolute_error: 105.3277
# Epoch 294/360
# 5/5 [==============================] - 0s 30ms/step - loss: 76.8622 - mean_absolute_error: 76.8622 - val_loss: 109.1696 - val_mean_absolute_error: 109.1696
# Epoch 295/360
# 5/5 [==============================] - 0s 27ms/step - loss: 75.5728 - mean_absolute_error: 75.5728 - val_loss: 108.3768 - val_mean_absolute_error: 108.3768
# Epoch 296/360
# 5/5 [==============================] - 0s 27ms/step - loss: 71.7615 - mean_absolute_error: 71.7615 - val_loss: 107.3314 - val_mean_absolute_error: 107.3314
# Epoch 297/360
# 5/5 [==============================] - 0s 31ms/step - loss: 71.4096 - mean_absolute_error: 71.4096 - val_loss: 105.2921 - val_mean_absolute_error: 105.2921
# Epoch 298/360
# 5/5 [==============================] - 0s 30ms/step - loss: 77.3202 - mean_absolute_error: 77.3202 - val_loss: 106.6525 - val_mean_absolute_error: 106.6525
# Epoch 299/360
# 5/5 [==============================] - 0s 31ms/step - loss: 73.7326 - mean_absolute_error: 73.7326 - val_loss: 109.0097 - val_mean_absolute_error: 109.0097
# Epoch 300/360
# 5/5 [==============================] - 0s 30ms/step - loss: 76.7146 - mean_absolute_error: 76.7146 - val_loss: 108.8684 - val_mean_absolute_error: 108.8684
# Epoch 301/360
# 5/5 [==============================] - 0s 27ms/step - loss: 73.7938 - mean_absolute_error: 73.7938 - val_loss: 107.2590 - val_mean_absolute_error: 107.2590
# Epoch 302/360
# 5/5 [==============================] - 0s 33ms/step - loss: 80.9675 - mean_absolute_error: 80.9675 - val_loss: 107.3395 - val_mean_absolute_error: 107.3395
# Epoch 303/360
# 5/5 [==============================] - 0s 27ms/step - loss: 76.1472 - mean_absolute_error: 76.1472 - val_loss: 108.1326 - val_mean_absolute_error: 108.1326
# Epoch 304/360
# 5/5 [==============================] - 0s 25ms/step - loss: 74.8370 - mean_absolute_error: 74.8370 - val_loss: 107.8824 - val_mean_absolute_error: 107.8824
# Epoch 305/360
# 5/5 [==============================] - 0s 35ms/step - loss: 76.5194 - mean_absolute_error: 76.5194 - val_loss: 108.1686 - val_mean_absolute_error: 108.1686
# Epoch 306/360
# 5/5 [==============================] - 0s 28ms/step - loss: 79.9959 - mean_absolute_error: 79.9959 - val_loss: 108.9968 - val_mean_absolute_error: 108.9968
# Epoch 307/360
# 5/5 [==============================] - 0s 25ms/step - loss: 79.4739 - mean_absolute_error: 79.4739 - val_loss: 101.2722 - val_mean_absolute_error: 101.2722
# Epoch 308/360
# 5/5 [==============================] - 0s 27ms/step - loss: 76.1514 - mean_absolute_error: 76.1514 - val_loss: 102.1665 - val_mean_absolute_error: 102.1665
# Epoch 309/360
# 5/5 [==============================] - 0s 27ms/step - loss: 75.7728 - mean_absolute_error: 75.7728 - val_loss: 108.3235 - val_mean_absolute_error: 108.3235
# Epoch 310/360
# 5/5 [==============================] - 0s 27ms/step - loss: 72.5710 - mean_absolute_error: 72.5710 - val_loss: 108.4464 - val_mean_absolute_error: 108.4464
# Epoch 311/360
# 5/5 [==============================] - 0s 28ms/step - loss: 73.7638 - mean_absolute_error: 73.7638 - val_loss: 110.4958 - val_mean_absolute_error: 110.4958
# Epoch 312/360
# 5/5 [==============================] - 0s 25ms/step - loss: 72.9827 - mean_absolute_error: 72.9827 - val_loss: 102.1821 - val_mean_absolute_error: 102.1821
# Epoch 313/360
# 5/5 [==============================] - 0s 36ms/step - loss: 75.1391 - mean_absolute_error: 75.1391 - val_loss: 104.3490 - val_mean_absolute_error: 104.3490
# Epoch 314/360
# 5/5 [==============================] - 0s 36ms/step - loss: 79.2182 - mean_absolute_error: 79.2182 - val_loss: 104.0743 - val_mean_absolute_error: 104.0743
# Epoch 315/360
# 5/5 [==============================] - 0s 29ms/step - loss: 74.7312 - mean_absolute_error: 74.7312 - val_loss: 102.8866 - val_mean_absolute_error: 102.8866
# Epoch 316/360
# 5/5 [==============================] - 0s 39ms/step - loss: 74.9879 - mean_absolute_error: 74.9879 - val_loss: 101.8414 - val_mean_absolute_error: 101.8414
# Epoch 317/360
# 5/5 [==============================] - 0s 46ms/step - loss: 75.9652 - mean_absolute_error: 75.9652 - val_loss: 103.0601 - val_mean_absolute_error: 103.0601
# Epoch 318/360
# 5/5 [==============================] - 0s 39ms/step - loss: 81.6176 - mean_absolute_error: 81.6176 - val_loss: 104.9838 - val_mean_absolute_error: 104.9838
# Epoch 319/360
# 5/5 [==============================] - 0s 38ms/step - loss: 74.5530 - mean_absolute_error: 74.5530 - val_loss: 107.7408 - val_mean_absolute_error: 107.7408
# Epoch 320/360
# 5/5 [==============================] - 0s 38ms/step - loss: 71.6854 - mean_absolute_error: 71.6854 - val_loss: 103.9757 - val_mean_absolute_error: 103.9757
# Epoch 321/360
# 5/5 [==============================] - 0s 34ms/step - loss: 72.8162 - mean_absolute_error: 72.8162 - val_loss: 101.9323 - val_mean_absolute_error: 101.9323
# Epoch 322/360
# 5/5 [==============================] - 0s 26ms/step - loss: 72.8446 - mean_absolute_error: 72.8446 - val_loss: 102.6625 - val_mean_absolute_error: 102.6625
# Epoch 323/360
# 5/5 [==============================] - 0s 26ms/step - loss: 77.1185 - mean_absolute_error: 77.1185 - val_loss: 101.4556 - val_mean_absolute_error: 101.4556
# Epoch 324/360
# 5/5 [==============================] - 0s 53ms/step - loss: 74.6794 - mean_absolute_error: 74.6794 - val_loss: 107.4166 - val_mean_absolute_error: 107.4166
# Epoch 325/360
# 5/5 [==============================] - 0s 25ms/step - loss: 74.7622 - mean_absolute_error: 74.7622 - val_loss: 105.9152 - val_mean_absolute_error: 105.9152
# Epoch 326/360
# 5/5 [==============================] - 0s 27ms/step - loss: 72.3848 - mean_absolute_error: 72.3848 - val_loss: 104.8801 - val_mean_absolute_error: 104.8801
# Epoch 327/360
# 5/5 [==============================] - 0s 26ms/step - loss: 75.0289 - mean_absolute_error: 75.0289 - val_loss: 104.4859 - val_mean_absolute_error: 104.4859
# Epoch 328/360
# 5/5 [==============================] - 0s 28ms/step - loss: 77.1238 - mean_absolute_error: 77.1238 - val_loss: 101.7686 - val_mean_absolute_error: 101.7686
# Epoch 329/360
# 5/5 [==============================] - 0s 24ms/step - loss: 70.8311 - mean_absolute_error: 70.8311 - val_loss: 103.4843 - val_mean_absolute_error: 103.4843
# Epoch 330/360
# 5/5 [==============================] - 0s 28ms/step - loss: 75.0168 - mean_absolute_error: 75.0168 - val_loss: 105.1627 - val_mean_absolute_error: 105.1627
# Epoch 331/360
# 5/5 [==============================] - 0s 26ms/step - loss: 74.4386 - mean_absolute_error: 74.4386 - val_loss: 98.0321 - val_mean_absolute_error: 98.0321
# Epoch 332/360
# 5/5 [==============================] - 0s 30ms/step - loss: 74.6877 - mean_absolute_error: 74.6877 - val_loss: 101.1892 - val_mean_absolute_error: 101.1892
# Epoch 333/360
# 5/5 [==============================] - 0s 25ms/step - loss: 76.6820 - mean_absolute_error: 76.6820 - val_loss: 105.0620 - val_mean_absolute_error: 105.0620
# Epoch 334/360
# 5/5 [==============================] - 0s 28ms/step - loss: 74.4073 - mean_absolute_error: 74.4073 - val_loss: 106.9403 - val_mean_absolute_error: 106.9403
# Epoch 335/360
# 5/5 [==============================] - 0s 29ms/step - loss: 74.9693 - mean_absolute_error: 74.9693 - val_loss: 103.2939 - val_mean_absolute_error: 103.2939
# Epoch 336/360
# 5/5 [==============================] - 0s 29ms/step - loss: 76.3031 - mean_absolute_error: 76.3031 - val_loss: 102.0695 - val_mean_absolute_error: 102.0695
# Epoch 337/360
# 5/5 [==============================] - 0s 30ms/step - loss: 72.3528 - mean_absolute_error: 72.3528 - val_loss: 101.6518 - val_mean_absolute_error: 101.6518
# Epoch 338/360
# 5/5 [==============================] - 0s 28ms/step - loss: 71.8285 - mean_absolute_error: 71.8285 - val_loss: 103.5655 - val_mean_absolute_error: 103.5655
# Epoch 339/360
# 5/5 [==============================] - 0s 41ms/step - loss: 79.3679 - mean_absolute_error: 79.3679 - val_loss: 105.0005 - val_mean_absolute_error: 105.0005
# Epoch 340/360
# 5/5 [==============================] - 0s 37ms/step - loss: 73.3591 - mean_absolute_error: 73.3591 - val_loss: 104.7686 - val_mean_absolute_error: 104.7686
# Epoch 341/360
# 5/5 [==============================] - 0s 36ms/step - loss: 75.0466 - mean_absolute_error: 75.0466 - val_loss: 103.2804 - val_mean_absolute_error: 103.2804
# Epoch 342/360
# 5/5 [==============================] - 0s 36ms/step - loss: 73.4382 - mean_absolute_error: 73.4382 - val_loss: 99.7117 - val_mean_absolute_error: 99.7117
# Epoch 343/360
# 5/5 [==============================] - 0s 33ms/step - loss: 73.0322 - mean_absolute_error: 73.0322 - val_loss: 98.4693 - val_mean_absolute_error: 98.4693
# Epoch 344/360
# 5/5 [==============================] - 0s 27ms/step - loss: 72.5624 - mean_absolute_error: 72.5624 - val_loss: 107.1626 - val_mean_absolute_error: 107.1626
# Epoch 345/360
# 5/5 [==============================] - 0s 30ms/step - loss: 72.0103 - mean_absolute_error: 72.0103 - val_loss: 104.4061 - val_mean_absolute_error: 104.4061
# Epoch 346/360
# 5/5 [==============================] - 0s 37ms/step - loss: 75.2748 - mean_absolute_error: 75.2748 - val_loss: 96.6930 - val_mean_absolute_error: 96.6930
# Epoch 347/360
# 5/5 [==============================] - 0s 37ms/step - loss: 73.6488 - mean_absolute_error: 73.6488 - val_loss: 104.7855 - val_mean_absolute_error: 104.7855
# Epoch 348/360
# 5/5 [==============================] - 0s 29ms/step - loss: 77.1650 - mean_absolute_error: 77.1650 - val_loss: 102.0446 - val_mean_absolute_error: 102.0446
# Epoch 349/360
# 5/5 [==============================] - 0s 26ms/step - loss: 73.1999 - mean_absolute_error: 73.1999 - val_loss: 96.2300 - val_mean_absolute_error: 96.2300
# Epoch 350/360
# 5/5 [==============================] - 0s 24ms/step - loss: 73.5776 - mean_absolute_error: 73.5776 - val_loss: 97.0221 - val_mean_absolute_error: 97.0221
# Epoch 351/360
# 5/5 [==============================] - 0s 30ms/step - loss: 76.6259 - mean_absolute_error: 76.6259 - val_loss: 99.2626 - val_mean_absolute_error: 99.2626
# Epoch 352/360
# 5/5 [==============================] - 0s 33ms/step - loss: 69.1200 - mean_absolute_error: 69.1200 - val_loss: 102.6542 - val_mean_absolute_error: 102.6542
# Epoch 353/360
# 5/5 [==============================] - 0s 40ms/step - loss: 77.0672 - mean_absolute_error: 77.0672 - val_loss: 104.1915 - val_mean_absolute_error: 104.1915
# Epoch 354/360
# 5/5 [==============================] - 0s 41ms/step - loss: 75.6543 - mean_absolute_error: 75.6543 - val_loss: 96.4890 - val_mean_absolute_error: 96.4890
# Epoch 355/360
# 5/5 [==============================] - 0s 34ms/step - loss: 74.3433 - mean_absolute_error: 74.3433 - val_loss: 96.5172 - val_mean_absolute_error: 96.5172
# Epoch 356/360
# 5/5 [==============================] - 0s 25ms/step - loss: 74.0932 - mean_absolute_error: 74.0932 - val_loss: 101.5351 - val_mean_absolute_error: 101.5351
# Epoch 357/360
# 5/5 [==============================] - 0s 36ms/step - loss: 68.6899 - mean_absolute_error: 68.6899 - val_loss: 102.8058 - val_mean_absolute_error: 102.8058
# Epoch 358/360
# 5/5 [==============================] - 0s 31ms/step - loss: 68.0816 - mean_absolute_error: 68.0816 - val_loss: 101.4457 - val_mean_absolute_error: 101.4457
# Epoch 359/360
# 5/5 [==============================] - 0s 26ms/step - loss: 73.0509 - mean_absolute_error: 73.0509 - val_loss: 98.3478 - val_mean_absolute_error: 98.3478
# Epoch 360/360
# 5/5 [==============================] - 0s 27ms/step - loss: 67.5682 - mean_absolute_error: 67.5682 - val_loss: 102.2594 - val_mean_absolute_error: 102.2594
# Wall time: 51.4 s

# %% [markdown]
# # Model Evaluation

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 200])
  plt.xlabel('Epoch')
  plt.ylabel('Error')
  plt.legend()
  plt.grid(True)
print(plot_loss(history))
# Out:
# None

# %%
pd.DataFrame(history.history).plot(figsize=(9, 6))
plt.grid(True)
plt.gca().set_ylim(0, 40) 
plt.show()

# %%
dnn_model.evaluate(test_features, y=test_labels, verbose=0)
# Out:
# [33840.73828125, 107.55992126464844, 0.0]

# %%
test_predictions = dnn_model.predict(test_features)

a = plt.axes(aspect='equal')
plt.scatter(test_labels['MPG'], test_predictions[:,0])
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 80]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
a = plt.axes(aspect='equal')
plt.scatter(test_labels['Weight'], test_predictions[:,1])
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 8000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
# Evaluate the regressor
mse_one = mean_squared_error(test_predictions[:,0], test_labels['MPG'])
mse_two = mean_squared_error(test_predictions[:,1], test_labels['Weight'])
print(f'MSE for first regressor: {mse_one} - second regressor: {mse_two}')
mae_one = mean_absolute_error(test_predictions[:,0], test_labels['MPG'])
mae_two = mean_absolute_error(test_predictions[:,1], test_labels['Weight'])
print(f'MAE for first regressor: {mae_one} - second regressor: {mae_two}')
# Out:
# MSE for first regressor: 12.240578213391455 - second regressor: 38872.136297532765
# MAE for first regressor: 2.4624226032159267 - second regressor: 143.2885241386218

# %%
#Save the model 
#dnn_model.save('my_model.h5')
#To restore the model use: dnn_model = tf.keras.models.load_model('my_model.h5')
