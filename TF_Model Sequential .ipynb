# %% [markdown]
# Regression and DNN Model

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import pydot

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# Get Dataset

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(url, names=column_names,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

dataset = raw_dataset.copy()
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1

# %%
#The dataset contains a few unknown values.
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
#Drop those rows to keep this initial tutorial simple.
dataset = dataset.dropna()

# %%
dataset['Origin'] = dataset['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
dataset = pd.get_dummies(dataset, prefix='', prefix_sep='')
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 393          82       0      0    1
# 394          82       1      0    0
# 395          82       0      0    1
# 396          82       0      0    1
# 397          82       0      0    1

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['MPG', 'Cylinders', 'Displacement', 'Weight']], diag_kind='kde')

# %%
train_dataset.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%  \
# MPG           314.0    23.310510    7.728652    10.0    17.00    22.0
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# Europe        314.0     0.178344    0.383413     0.0     0.00     0.0
# Japan         314.0     0.197452    0.398712     0.0     0.00     0.0
# USA           314.0     0.624204    0.485101     0.0     0.00     1.0
#
#                   75%     max
# MPG             28.95    46.6
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# Europe           0.00     1.0
# Japan            0.00     1.0
# USA              1.00     1.0

# %%
#Separate the target value, the "label", from the features. This label is the value that you will train the model to predict.
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop('MPG')
train_labels = train_features.pop('Cylinders')
test_labels = test_features.pop('MPG')
test_labels = test_features.pop('Cylinders')

print(train_labels)
# Out:
# 146    4
# 282    4
# 69     8
# 378    4
# 331    4
#       ..
# 281    6
# 229    8
# 150    4
# 145    4
# 182    4
# Name: Cylinders, Length: 314, dtype: int64

# %%
#In the table of statistics it's easy to see how different the ranges of each feature are.
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#                      mean         std
# MPG             23.310510    7.728652
# Cylinders        5.477707    1.699788
# Displacement   195.318471  104.331589
# Horsepower     104.869427   38.096214
# Weight        2990.251592  843.898596
# Acceleration    15.559236    2.789230
# Model Year      75.898089    3.675642
# Europe           0.178344    0.383413
# Japan            0.197452    0.398712
# USA              0.624204    0.485101

# %%
#Normalization

normalizer = preprocessing.Normalization()

normalizer.adapt(np.array(train_features))

print(normalizer.mean.numpy())

print(type(normalizer))
# Out:
# [ 195.318  104.869 2990.252   15.559   75.898    0.178    0.197    0.624]
# <class 'tensorflow.python.keras.layers.preprocessing.normalization.Normalization'>

# %%
first = np.array(train_features[:1])
tx = np.array(train_features)


with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[  90.    75.  2125.    14.5   74.     0.     0.     1. ]]
#
# Normalized: [[-1.01 -0.79 -1.03 -0.38 -0.52 -0.47 -0.5   0.78]]

# %%
horsepower = np.array(train_features['Horsepower'])

horsepower_normalizer = preprocessing.Normalization(input_shape=[1,])
horsepower_normalizer.adapt(horsepower)

# %% [markdown]
# Keras Functional API

# %%
def build_and_compile_model(norm):
    model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation=tf.nn.relu, input_shape=(8,)),  # input shape required
  tf.keras.layers.Dense(10, activation=tf.nn.relu),
  tf.keras.layers.Dense(2)
])
    model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001),metrics=["accuracy"])
    return model

# %%
dnn_model = build_and_compile_model(normalizer)

# %%
dnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                50
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(train_features, train_labels, batch_size=60, epochs=60, validation_split=0.001)
# Out:
# Epoch 1/60
# 6/6 [==============================] - 1s 81ms/step - loss: 294.4962 - accuracy: 0.0000e+00 - val_loss: 192.7792 - val_accuracy: 0.0000e+00
# Epoch 2/60
# 6/6 [==============================] - 0s 19ms/step - loss: 230.5899 - accuracy: 0.0000e+00 - val_loss: 144.1106 - val_accuracy: 0.0000e+00
# Epoch 3/60
# 6/6 [==============================] - 0s 18ms/step - loss: 172.1889 - accuracy: 0.0000e+00 - val_loss: 123.3271 - val_accuracy: 0.0000e+00
# Epoch 4/60
# 6/6 [==============================] - 0s 18ms/step - loss: 145.5575 - accuracy: 0.0000e+00 - val_loss: 111.6404 - val_accuracy: 0.0000e+00
# Epoch 5/60
# 6/6 [==============================] - 0s 21ms/step - loss: 124.9546 - accuracy: 0.0000e+00 - val_loss: 91.3982 - val_accuracy: 0.0000e+00
# Epoch 6/60
# 6/6 [==============================] - 0s 19ms/step - loss: 112.6140 - accuracy: 0.0000e+00 - val_loss: 82.2137 - val_accuracy: 0.0000e+00
# Epoch 7/60
# 6/6 [==============================] - 0s 20ms/step - loss: 98.0356 - accuracy: 0.0000e+00 - val_loss: 71.3929 - val_accuracy: 0.0000e+00
# Epoch 8/60
# 6/6 [==============================] - 0s 20ms/step - loss: 85.1662 - accuracy: 0.0000e+00 - val_loss: 62.2474 - val_accuracy: 0.0000e+00
# Epoch 9/60
# 6/6 [==============================] - 0s 19ms/step - loss: 73.6326 - accuracy: 0.0000e+00 - val_loss: 53.5968 - val_accuracy: 0.0000e+00
# Epoch 10/60
# 6/6 [==============================] - 0s 18ms/step - loss: 62.5100 - accuracy: 0.0000e+00 - val_loss: 44.3900 - val_accuracy: 0.0000e+00
# 6/6 [==============================] - 0s 19ms/step - loss: 1.5583 - accuracy: 0.0000e+00 - val_loss: 1.1362 - val_accuracy: 0.0000e+00
# Epoch 48/60
# 6/6 [==============================] - 0s 18ms/step - loss: 1.4132 - accuracy: 0.0000e+00 - val_loss: 0.8200 - val_accuracy: 0.0000e+00
# Epoch 49/60
# 6/6 [==============================] - 0s 19ms/step - loss: 1.4386 - accuracy: 0.0000e+00 - val_loss: 1.0233 - val_accuracy: 0.0000e+00
# Epoch 50/60
# 6/6 [==============================] - 0s 18ms/step - loss: 1.4194 - accuracy: 0.0000e+00 - val_loss: 1.0791 - val_accuracy: 0.0000e+00
# Epoch 51/60
# 6/6 [==============================] - 0s 21ms/step - loss: 1.3585 - accuracy: 0.0000e+00 - val_loss: 1.2028 - val_accuracy: 0.0000e+00
# Epoch 52/60
# 6/6 [==============================] - 0s 26ms/step - loss: 1.3738 - accuracy: 0.0000e+00 - val_loss: 1.2244 - val_accuracy: 0.0000e+00
# Epoch 53/60
# 6/6 [==============================] - 0s 24ms/step - loss: 1.3109 - accuracy: 0.0000e+00 - val_loss: 1.0232 - val_accuracy: 0.0000e+00
# Epoch 54/60
# 6/6 [==============================] - 0s 27ms/step - loss: 1.2659 - accuracy: 0.0000e+00 - val_loss: 0.9936 - val_accuracy: 0.0000e+00
# Epoch 55/60
# 6/6 [==============================] - 0s 18ms/step - loss: 1.3259 - accuracy: 0.0000e+00 - val_loss: 1.0222 - val_accuracy: 0.0000e+00
# Epoch 56/60
# 6/6 [==============================] - 0s 23ms/step - loss: 1.2557 - accuracy: 0.0000e+00 - val_loss: 1.1189 - val_accuracy: 0.0000e+00
# Epoch 57/60
# 6/6 [==============================] - 0s 22ms/step - loss: 1.3160 - accuracy: 0.0000e+00 - val_loss: 1.0051 - val_accuracy: 0.0000e+00
# Epoch 58/60
# 6/6 [==============================] - 0s 24ms/step - loss: 1.3417 - accuracy: 0.0000e+00 - val_loss: 1.0709 - val_accuracy: 0.0000e+00
# Epoch 59/60
# 6/6 [==============================] - 0s 24ms/step - loss: 1.2674 - accuracy: 0.0000e+00 - val_loss: 1.0973 - val_accuracy: 0.0000e+00
# Epoch 60/60
# 6/6 [==============================] - 0s 22ms/step - loss: 1.1860 - accuracy: 0.0000e+00 - val_loss: 1.0288 - val_accuracy: 0.0000e+00
# Wall time: 7.41 s

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 5])
  plt.xlabel('Epoch')
  plt.ylabel('Error')
  plt.legend()
  plt.grid(True)
print(plot_loss(history))
# Out:
# None

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 4) 
plt.show()

# %%
dnn_model.evaluate(test_features, test_labels, verbose=0)
# Out:
# [16.879362106323242, 2.4387359619140625, 14.440627098083496, 0.0, 0.0]

# %%
test_predictions = dnn_model.predict()

a = plt.axes(aspect='equal')
plt.scatter(test_labels('MPG'), test_predictions('MPG'))
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-5f42f6e6a37c> in <module>
# ----> 1 test_predictions = dnn_model.predict()
#       2
#       3 a = plt.axes(aspect='equal')
#       4 plt.scatter(test_labels('MPG'), test_predictions('MPG'))
#       5 plt.xlabel('True Values [MPG]')
#
# TypeError: predict() missing 1 required positional argument: 'x'
