# %% [markdown]
# Regression and DNN Model

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import pydot

# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# Get Dataset

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(url, names=column_names,
                          na_values='?', comment='\t',
                          sep=' ', skipinitialspace=True)

dataset = raw_dataset.copy()
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1

# %%
#The dataset contains a few unknown values.
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
#Drop those rows to keep this initial tutorial simple.
dataset = dataset.dropna()

# %%
dataset['Origin'] = dataset['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
dataset = pd.get_dummies(dataset, prefix='', prefix_sep='')
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 393          82       0      0    1
# 394          82       1      0    0
# 395          82       0      0    1
# 396          82       0      0    1
# 397          82       0      0    1

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['MPG', 'Cylinders', 'Displacement', 'Weight']], diag_kind='kde')

# %%
train_dataset.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%  \
# MPG           314.0    23.310510    7.728652    10.0    17.00    22.0
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# Europe        314.0     0.178344    0.383413     0.0     0.00     0.0
# Japan         314.0     0.197452    0.398712     0.0     0.00     0.0
# USA           314.0     0.624204    0.485101     0.0     0.00     1.0
#
#                   75%     max
# MPG             28.95    46.6
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# Europe           0.00     1.0
# Japan            0.00     1.0
# USA              1.00     1.0

# %%
#Separate the target value, the "label", from the features. This label is the value that you will train the model to predict.
train_features = train_dataset.copy()
test_features = test_dataset.copy()


train_labels = train_features[['MPG','Cylinders']].copy()
train_features = train_features.drop(['MPG','Cylinders'], axis=1)
test_labels = test_features[['MPG','Cylinders']].copy()
test_features = test_features.drop(['MPG','Cylinders'], axis=1)

print(test_labels.head())
# Out:
#      MPG  Cylinders
# 9   15.0          8
# 25  10.0          8
# 28   9.0          8
# 31  25.0          4
# 33  19.0          6

# %%
#In the table of statistics it's easy to see how different the ranges of each feature are.
train_dataset.describe().transpose()[['mean', 'std']]
# Out:
#                      mean         std
# MPG             23.310510    7.728652
# Cylinders        5.477707    1.699788
# Displacement   195.318471  104.331589
# Horsepower     104.869427   38.096214
# Weight        2990.251592  843.898596
# Acceleration    15.559236    2.789230
# Model Year      75.898089    3.675642
# Europe           0.178344    0.383413
# Japan            0.197452    0.398712
# USA              0.624204    0.485101

# %%
#Normalization

normalizer = preprocessing.Normalization()

normalizer.adapt(np.array(train_features))

print(normalizer.mean.numpy())

print(type(normalizer))
# Out:
# [ 195.318  104.869 2990.252   15.559   75.898    0.178    0.197    0.624]
# <class 'tensorflow.python.keras.layers.preprocessing.normalization.Normalization'>

# %%
first = np.array(train_features[:1])
tx = np.array(train_features)


with np.printoptions(precision=2, suppress=True):
  print('First example:', first)
  print()
  print('Normalized:', normalizer(first).numpy())
# Out:
# First example: [[  90.    75.  2125.    14.5   74.     0.     0.     1. ]]
#
# Normalized: [[-1.01 -0.79 -1.03 -0.38 -0.52 -0.47 -0.5   0.78]]

# %% [markdown]
# Keras Sequential

# %%
def build_and_compile_model_s(norm):
    model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation=tf.nn.relu, input_shape=(8,)),  # input shape required
  tf.keras.layers.Dense(10, activation=tf.nn.relu),
  tf.keras.layers.Dense(2)
])
    model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001),metrics=["accuracy"])
    return model

def build_and_compile_model_f(norm):
    inputs = keras.Input(shape=(8,))

    dense = layers.Dense(64, activation="relu")
    x = dense(inputs)

    x = layers.Dense(64, activation="relu")(x)

    output_mph = layers.Dense(1)(x)
    output_cyl = layers.Dense(1)(x)


    model = keras.Model(inputs=inputs, outputs=[output_mph,output_cyl])
    model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001),metrics=["accuracy"])
    return model

# %%
dnn_model = build_and_compile_model_s(train_features)

# %%
dnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                90
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 222
# Trainable params: 222
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(train_features, train_labels, batch_size=60, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 55ms/step - loss: 10.1015 - accuracy: 0.8765 - val_loss: 10.7650 - val_accuracy: 0.7937
# Epoch 2/100
# 5/5 [==============================] - 0s 25ms/step - loss: 9.8174 - accuracy: 0.7968 - val_loss: 10.6483 - val_accuracy: 0.8413
# Epoch 3/100
# 5/5 [==============================] - 0s 22ms/step - loss: 9.6666 - accuracy: 0.8207 - val_loss: 10.4809 - val_accuracy: 0.7937
# Epoch 4/100
# 5/5 [==============================] - 0s 22ms/step - loss: 9.5714 - accuracy: 0.7729 - val_loss: 10.6242 - val_accuracy: 0.9048
# Epoch 5/100
# 5/5 [==============================] - 0s 22ms/step - loss: 9.6623 - accuracy: 0.9004 - val_loss: 10.6150 - val_accuracy: 0.7619
# Epoch 6/100
# 5/5 [==============================] - 0s 22ms/step - loss: 9.8225 - accuracy: 0.7649 - val_loss: 10.1573 - val_accuracy: 0.8571
# Epoch 7/100
# 5/5 [==============================] - 0s 22ms/step - loss: 9.4805 - accuracy: 0.7928 - val_loss: 10.1960 - val_accuracy: 0.8730
# Epoch 8/100
# 5/5 [==============================] - 0s 23ms/step - loss: 9.4856 - accuracy: 0.8247 - val_loss: 9.9704 - val_accuracy: 0.7937
# 5/5 [==============================] - 0s 22ms/step - loss: 6.0785 - accuracy: 0.8526 - val_loss: 6.1433 - val_accuracy: 0.9048
# Epoch 86/100
# 5/5 [==============================] - 0s 23ms/step - loss: 5.7098 - accuracy: 0.8805 - val_loss: 6.2958 - val_accuracy: 0.8730
# Epoch 87/100
# 5/5 [==============================] - 0s 24ms/step - loss: 5.6028 - accuracy: 0.8685 - val_loss: 6.4401 - val_accuracy: 0.8730
# Epoch 88/100
# 5/5 [==============================] - 0s 32ms/step - loss: 5.8188 - accuracy: 0.8725 - val_loss: 6.1165 - val_accuracy: 0.9048
# Epoch 89/100
# 5/5 [==============================] - 0s 22ms/step - loss: 5.9548 - accuracy: 0.8526 - val_loss: 6.7127 - val_accuracy: 0.9206
# Epoch 90/100
# 5/5 [==============================] - 0s 23ms/step - loss: 6.0059 - accuracy: 0.8645 - val_loss: 6.8826 - val_accuracy: 0.9206
# Epoch 91/100
# 5/5 [==============================] - 0s 23ms/step - loss: 5.9721 - accuracy: 0.9124 - val_loss: 7.5765 - val_accuracy: 0.7619
# Epoch 92/100
# 5/5 [==============================] - 0s 22ms/step - loss: 6.0166 - accuracy: 0.8606 - val_loss: 6.4094 - val_accuracy: 0.9206
# Epoch 93/100
# 5/5 [==============================] - 0s 22ms/step - loss: 5.6693 - accuracy: 0.8486 - val_loss: 7.0377 - val_accuracy: 0.8889
# Epoch 94/100
# 5/5 [==============================] - 0s 22ms/step - loss: 6.2845 - accuracy: 0.8566 - val_loss: 7.4736 - val_accuracy: 0.9524
# Epoch 95/100
# 5/5 [==============================] - 0s 24ms/step - loss: 6.8497 - accuracy: 0.9602 - val_loss: 7.6855 - val_accuracy: 0.7143
# Epoch 96/100
# 5/5 [==============================] - 0s 22ms/step - loss: 6.5850 - accuracy: 0.8606 - val_loss: 5.8165 - val_accuracy: 0.9206
# Epoch 97/100
# 5/5 [==============================] - 0s 22ms/step - loss: 6.0104 - accuracy: 0.8207 - val_loss: 6.1996 - val_accuracy: 0.9524
# Epoch 98/100
# 5/5 [==============================] - 0s 22ms/step - loss: 5.5375 - accuracy: 0.9363 - val_loss: 6.7224 - val_accuracy: 0.8095
# Epoch 99/100
# 5/5 [==============================] - 0s 24ms/step - loss: 5.8860 - accuracy: 0.8606 - val_loss: 6.1313 - val_accuracy: 0.8571
# Epoch 100/100
# 5/5 [==============================] - 0s 21ms/step - loss: 6.0026 - accuracy: 0.7928 - val_loss: 6.7784 - val_accuracy: 0.9524
# Wall time: 10.4 s

# %%
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 20])
  plt.xlabel('Epoch')
  plt.ylabel('Error')
  plt.legend()
  plt.grid(True)
print(plot_loss(history))
# Out:
# None

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) 
plt.show()

# %%
dnn_model.evaluate(test_features, test_labels, verbose=0)
# Out:
# [6.926834583282471, 0.9743589758872986]

# %%
test_predictions = dnn_model.predict(test_features).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
lims = [0, 50]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
# Out:
# 9      8
# 25     8
# 28     8
# 31     4
# 33     6
#       ..
# 369    4
# 375    4
# 382    4
# 384    4
# 396    4
# Name: Cylinders, Length: 78, dtype: int64
